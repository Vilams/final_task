# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# считывание данных с одного файла
names1 = pd.read_table('C:\\Users\\79146\\Desktop\\soldatov_ks-data-69c734973a6a\\babynames\\yob1880.txt', sep=',', names=['name', 'sex', 'number'])
names1
# Out:
#            name sex  number
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# ...         ...  ..     ...
# 1995     Woodie   M       5
# 1996     Worthy   M       5
# 1997     Wright   M       5
# 1998       York   M       5
# 1999  Zachariah   M       5
#
# [2000 rows x 3 columns]

# %%
# Вывод общего числа родившихся младенцев каждого пола
names1.groupby('sex').size()
# Out:
# sex
# F     942
# M    1058
# dtype: int64

# %%
# считаем все файлы
years = range(1880, 2011)
pieces = []
for i in years:
    df = pd.read_table('C:\\Users\\79146\\Desktop\\soldatov_ks-data-69c734973a6a\\babynames\\yob%d.txt'%i, sep = ',', engine = 'python' , names=['name', 'sex', 'number'])
    df['year'] = i
    pieces.append(df)
    data = pd.concat(pieces, ignore_index = True)
data
# Out:
#               name sex  number  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# ...            ...  ..     ...   ...
# 1690779    Zymaire   M       5  2010
# 1690780     Zyonne   M       5  2010
# 1690781  Zyquarius   M       5  2010
# 1690782      Zyran   M       5  2010
# 1690783      Zzyzx   M       5  2010
#
# [1690784 rows x 4 columns]

# %%
# сгруппируем основдой датафрейм по году и полу
YearsSexCount = data.groupby(['year', 'sex']).size()
YearsSexCount
# Out:
# year  sex
# 1880  F        942
#       M       1058
# 1881  F        938
#       M        997
# 1882  F       1028
#              ...
# 2008  M      14590
# 2009  F      20123
#       M      14479
# 2010  F      19698
#       M      14140
# Length: 262, dtype: int64

# %%
# передаём нужные значения в массивы абсциссы и ординат, строим график
abscissa = []
ordinada_F = []
ordinada_M = []

for i in range(1880, 2011):
    abscissa.append(i)

for i in range(0, 262):
    if i % 2 == 0:
        ordinada_F.append(YearsSexCount.iloc[i])
    else:
        ordinada_M.append(YearsSexCount.iloc[i])
        
plt.plot(abscissa, ordinada_F, label='Famale')
plt.plot(abscissa, ordinada_M, label='Male')
plt.legend()

# %%
# Вывод пропоорций имён
data['proportion'] = data['number'] / sum(data['number'])
data
# Out:
#               name sex  number  year    proportion
# 0             Mary   F    7065  1880  2.191359e-05
# 1             Anna   F    2604  1880  8.076855e-06
# 2             Emma   F    2003  1880  6.212727e-06
# 3        Elizabeth   F    1939  1880  6.014217e-06
# 4           Minnie   F    1746  1880  5.415587e-06
# ...            ...  ..     ...   ...           ...
# 1690779    Zymaire   M       5  2010  1.550855e-08
# 1690780     Zyonne   M       5  2010  1.550855e-08
# 1690781  Zyquarius   M       5  2010  1.550855e-08
# 1690782      Zyran   M       5  2010  1.550855e-08
# 1690783      Zzyzx   M       5  2010  1.550855e-08
#
# [1690784 rows x 5 columns]

# %%
# Вывод графика соотношения имён

years = []
for i in range(1880, 2011):
    years.append(i)
Johnny = []
Natalie = []
Bob = []
Vladislav = []
s = []
for i in range(1880, 2011):
    local_df = pd.read_table('C:\\Users\\79146\\Desktop\\soldatov_ks-data-69c734973a6a\\babynames\\yob%d.txt'%i, sep=',', names=['name', 'sex', 'number'])
    summ_count = sum(local_df['number'])
    J_count= sum(local_df[local_df['name'] == 'Johnny']['number'])
    Johnny.append(J_count / summ_count)
    N_count= sum(local_df[local_df['name'] == 'Natalie']['number'])
    Natalie.append(N_count / summ_count)
    B_count= sum(local_df[local_df['name'] == 'Bob']['number'])
    Bob.append(B_count / summ_count)
    V_count= sum(local_df[local_df['name'] == 'Vlad']['number'])
    Vladislav.append(V_count / summ_count)


plt.plot(years, Johnny, label='Johnny')
plt.plot(years, Natalie, label='Natalie')
plt.plot(years, Bob, label='Bob')
plt.plot(years, Vladislav, label='Vlad')
plt.legend()

# %%
# последнее задание
max_count = []
for i in range(1880, 2011):
    loc = pd.read_table('C:\\Users\\79146\\Desktop\\soldatov_ks-data-69c734973a6a\\babynames\\yob%d.txt'%i, sep=',', names=['name', 'sex', 'number'])
    sort = loc.sort_values(by='number', ascending=False)
    max_count.append(sort['number'].iloc[0])
print('year : max : name')
for i in range(131):
    print(years[i], ':', max_count[i])
# Out:
# year : max : name
# 1880 : 9655
# 1881 : 8769
# 1882 : 9557
# 1883 : 8894
# 1884 : 9387
# 1885 : 9128
# 1886 : 9891
# 1887 : 9888
# 1888 : 11754
# 1889 : 11649
# 1890 : 12078
# 1891 : 11704
# 1892 : 13174
# 1893 : 12784
# 1894 : 13151
# 1895 : 13446
# 1896 : 13811
# 1897 : 13412
# 1898 : 14406
# 1899 : 13172
# 1900 : 16710
# 1901 : 13137
# 1902 : 14485
# 1903 : 14275
# 1904 : 14962
# 1905 : 16067
# 1906 : 16371
# 1907 : 17579
# 1908 : 18664
# 1909 : 19256
# 1910 : 22840
# 1911 : 24385
# 1912 : 32295
# 1913 : 36631
# 1914 : 45341
# 1915 : 58184
# 1916 : 61428
# 1917 : 64270
# 1918 : 67375
# 1919 : 65839
# 1920 : 70974
# 1921 : 73980
# 1922 : 72156
# 1923 : 71636
# 1924 : 73505
# 1925 : 70594
# 1926 : 67830
# 1927 : 70594
# 1928 : 66867
# 1929 : 63502
# 1930 : 64110
# 1931 : 60492
# 1932 : 59859
# 1933 : 55477
# 1934 : 56898
# 1935 : 56501
# 1936 : 58462
# 1937 : 61799
# 1938 : 62246
# 1939 : 59623
# 1940 : 62454
# 1941 : 66696
# 1942 : 77155
# 1943 : 80231
# 1944 : 76935
# 1945 : 74475
# 1946 : 87382
# 1947 : 99651
# 1948 : 96185
# 1949 : 90952
# 1950 : 86094
# 1951 : 87046
# 1952 : 87060
# 1953 : 86081
# 1954 : 88462
# 1955 : 88285
# 1956 : 90587
# 1957 : 92700
# 1958 : 90468
# 1959 : 85277
# 1960 : 85917
# 1961 : 86898
# 1962 : 85022
# 1963 : 83779
# 1964 : 82654
# 1965 : 81041
# 1966 : 79993
# 1967 : 82447
# 1968 : 82026
# 1969 : 85216
# 1970 : 85298
# 1971 : 77579
# 1972 : 71412
# 1973 : 67836
# 1974 : 67554
# 1975 : 68433
# 1976 : 66955
# 1977 : 67590
# 1978 : 67113
# 1979 : 67712
# 1980 : 68619
# 1981 : 68713
# 1982 : 68151
# 1983 : 67949
# 1984 : 67686
# 1985 : 64862
# 1986 : 64164
# 1987 : 63621
# 1988 : 64092
# 1989 : 65384
# 1990 : 65268
# 1991 : 60780
# 1992 : 54364
# 1993 : 49551
# 1994 : 44461
# 1995 : 41396
# 1996 : 38359
# 1997 : 37542
# 1998 : 36604
# 1999 : 35335
# 2000 : 34454
# 2001 : 32509
# 2002 : 30541
# 2003 : 29601
# 2004 : 27854
# 2005 : 25794
# 2006 : 24797
# 2007 : 24216
# 2008 : 22507
# 2009 : 22222
# 2010 : 22731
